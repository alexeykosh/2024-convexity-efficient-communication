# %%
import numpy as np
from collections import defaultdict
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import normalized_mutual_info_score
from sklearn.metrics.pairwise import euclidean_distances
from collections import Counter

from src.colorconv import ConvexCluster
from src.util import (compression,
                      informativeness,
                      non_dominated_front)
from src.experiment import (Experiment,
                            calculate_normalized_mutual_info, 
                            generate_lexicons, 
                            plot_last_lexicons,
                            efficiency_simplicity_analysis,)

import statsmodels.api as sm

np.seterr(divide='ignore', invalid='ignore')

sns.set(context='paper', style='ticks', font_scale=1)

# %%
NUMBER = 2
SHAPE = (5, 5)

# %%
coords = np.array(np.meshgrid(np.arange(SHAPE[0]), np.arange(SHAPE[1]))).T.reshape(-1, 2)
coords = [tuple(i) for i in coords]
# dictionary mapping coords to themselves
coords_dict = defaultdict(list)
for i, coord in enumerate(coords):
    coords_dict[tuple(coord)] = tuple(coord)

# %%
# reverse dictionary mapping coords to themselves
coords_dict_rev = {}
for i, coord in enumerate(coords):
    coords_dict_rev[tuple(coord)] = tuple(coord)

# %%
# plot 4 x 4 possible color clusters with parameter smooth in [0.1, 0.25, 0.5, 1] and conn in [0.1, 0.25, 0.5, 1]
fig, ax = plt.subplots(5, 5, figsize=(5, 5))

smooth_values = [0.05, 0.25, 0.5, 0.75, 1]
conn_values = [0.0005, 0.01, 0.1, 0.5, 1]
conn_values = [_ for _ in reversed(conn_values)]

for i, smooth in enumerate(smooth_values):
    for j, conn in enumerate(conn_values):
        a = ConvexCluster(X = np.zeros(SHAPE), 
                                d = 1, 
                                N = NUMBER, 
                                s = smooth, 
                                c = conn,
                                coords=coords,
                                reverse_labels=coords_dict)
        labels = a.run()
        ax[i, j].imshow(labels, 
                        cmap='tab10', 
                        interpolation='none')
        ax[i, j].set_xticks([])
        ax[i, j].set_yticks([])
        ax[i, j].set_title(f'C = {a.degree_of_convexity():.2f}', fontsize=12)
        # remove border
        for spine in ax[i, j].spines.values():
            spine.set_visible(False)
        # ax[i, j].set_title(f'MDL = {mdl(labels):.2f}')
        
# Label the conn values on the y-axis
for i, conn in enumerate(conn_values):
    ax[i, 0].set_ylabel('c =' + str(conn), fontsize=10, style='italic')

# Label the smooth values on the x-axis
for j, smooth in enumerate(smooth_values):
    ax[4, j].set_xlabel('s = ' + str(smooth), fontsize=10, style='italic')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Single N example

# %%
n_iter = 20
n_rounds = 100

# %%
L, d_c = generate_lexicons(NUMBER, SHAPE, 1000, coords=coords, coords_dict=coords_dict)

# %%
len(d_c)
# Out:
# 1000

# %%
plt.figure(figsize=(8, 3))
plt.hist(d_c, bins=20, density=True)
plt.xlabel('Degree of convexity')
plt.ylabel('Density')
sns.despine()
plt.xlim(0, 1)
plt.show()

# %%
# plot distribution of simplicity
s = [compression(subarray) for subarray in L]
# normalize simplicity
s = np.array((s - np.min(s)) / (np.max(s) - np.min(s))) ** 0.1

plt.figure(figsize=(8, 3))
plt.hist(s, bins=20, density=True)
plt.xlabel('Simplicity')
plt.ylabel('Density')
plt.xlim(0, 1)
sns.despine()

# %%
a = Experiment(alpha=10, 
               shape=SHAPE, 
               n=len(L), 
               n_iter=n_iter, 
               n_rounds=n_rounds,
               prior=np.ones(SHAPE[0] * SHAPE[1]) / (SHAPE[0] * SHAPE[1]), 
               convex=True, # convexity bias
               threshold=0, # no treshold
               beta=0.1, # strong convexity bias
               Lexicons=L,
               simple=False,
               convexities=d_c) # simplicity bias)
a.run()
mi_convex = calculate_normalized_mutual_info(a, n_iter, n_rounds)

# %%
b = Experiment(alpha=10, 
               shape=SHAPE, 
               n=len(L), 
               n_iter=n_iter, 
               n_rounds=n_rounds,
               prior= np.ones(SHAPE[0] * SHAPE[1]) / (SHAPE[0] * SHAPE[1]), #prior_m_matrix.ravel()
               convex=False, # no convexity bias
               threshold=0, # no treshold
               beta=1, # no skew towards convex lexicons
               Lexicons=L,
               simple=False,
               convexities=d_c) # simplicity bias)
b.run()
mi_nconvex = calculate_normalized_mutual_info(b, n_iter, n_rounds)

# %%
c = Experiment(alpha=10,
                shape=SHAPE, 
                n=len(L), 
                n_iter=n_iter, 
                n_rounds=n_rounds,
                prior= np.ones(SHAPE[0] * SHAPE[1]) / (SHAPE[0] * SHAPE[1]), 
                convex=False, # convexity bias
                threshold=0, # no treshold
                beta=0.1, # simplicity bias
                Lexicons=L,
                simple=True,
                convexities=d_c) # simplicity bias)
c.run()
mi_simple = calculate_normalized_mutual_info(c, n_iter, n_rounds)

# %%
# d = Experiment(alpha=1,
#                 shape=shape, 
#                 n=len(L), 
#                 n_iter=n_iter, 
#                 n_rounds=n_rounds,
#                 prior= np.ones(shape[0] * shape[1]) / (shape[0] * shape[1]), 
#                 convex=False, # convexity bias
#                 treshold=0.9, # high threshold on convexity
#                 beta=1, # simplicity bias
#                 Lexicons=L,
#                 simple=True,
#                 convexities=d_c) # simplicity bias)
# d.run()
# mi_simple_conv = calculate_normalized_mutual_info(d, n_iter, n_rounds)

# %%
# generate 1000 random matrices and compute the baseline
baseline = []

for i in range(1000):
    baseline.append(normalized_mutual_info_score(L[np.random.choice(range(len(L)))].ravel(),   
                                                 L[np.random.choice(range(len(L)))].ravel()))

# %%
fig, ax = plt.subplots(figsize=(8, 3))
# for mi in mis:
#     plt.plot(mi, color = 'blue', alpha=0.05, linewidth=3)
# plot mean mutual information
# plot the baseline
plt.axhline(y=np.mean(baseline), 
            color='r', 
            linestyle='--', 
            linewidth=2, 
            alpha=1)
sns.lineplot(x="variable", 
             y="value", 
             data=mi_convex,
             linewidth=3,
             label='convexity bias')
sns.lineplot(x="variable", 
             y="value", 
             data=mi_nconvex,
             linewidth=3,
             label='non biased')
sns.lineplot(x="variable",
             y="value",
             data=mi_simple,
             linewidth=3,
             label='simplicity bias')
# sns.lineplot(x="variable",
#              y="value",
#              data=mi_simple_conv,
#              linewidth=3,
#              label='simplicity bias + convexity treshold')
plt.ylim(0, 1.05)
plt.xlabel('Round')
plt.ylabel('Mutual Information')
plt.tight_layout()
plt.legend()
# log space y 
# ax.set_yscale('log')
# ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
# ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
# ax.minorticks_on()
plt.margins(x=0)
plt.show()

# %%
# for every variable in mi_nconvex, add a new column with range(n_iter) and then melt the dataframe
mi_nconvex['group'] = list(range(n_iter)) * n_rounds
mi_convex['group'] = list(range(n_iter)) * n_rounds
mi_simple['group'] = list(range(n_iter)) * n_rounds
# mi_simple_conv['group'] = list(range(n_iter)) * n_rounds

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 2))
# remove borders on the top and right in all subplots
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)

# Convex subplot
ax1.set_title('Convexity bias', fontsize=12)
for group in mi_convex.group.unique():
    if group % 2 == 0:
        ax1.plot(range(n_rounds), mi_convex[mi_convex.group == group].value, 
                 color='grey', alpha=0.01, linewidth=5)

# plot mean mutual information by grouping by variable
ax1.plot(range(n_rounds), mi_convex.groupby('variable').value.mean(), color='blue', linewidth=3)

# Non-convex subplot
ax2.set_title('Unbiased',  fontsize=12)
for group in mi_nconvex.group.unique():
    if group % 2 == 0:
        ax2.plot(range(n_rounds), mi_nconvex[mi_nconvex.group == group].value, 
                 color='grey', alpha=0.01, linewidth=5)

# plot mean mutual information by grouping by variable
ax2.plot(range(n_rounds), mi_nconvex.groupby('variable').value.mean(), color='orange', linewidth=5)

# Simplicity subplot
ax3.set_title('Simplicity bias', fontsize=12)
for group in mi_simple.group.unique():
    if group % 2 == 0:
        ax3.plot(range(n_rounds), mi_simple[mi_simple.group == group].value, 
                 color='grey', alpha=0.01, linewidth=5)
        
# plot mean mutual information by grouping by variable
ax3.plot(range(n_rounds), mi_simple.groupby('variable').value.mean(), color='red', linewidth=5)
        
# # Simplicity + convexity treshold subplot
# ax4.set_title('Simplicity + treshold', fontsize=12)
# for group in mi_simple_conv.group.unique():
#     if group % 2 == 0:
#         ax4.plot(range(n_rounds), mi_simple_conv[mi_simple_conv.group == group].value, 
#                  color='grey', alpha=0.1, linewidth=5)

# ax4.plot(range(n_rounds), mi_simple_conv.groupby('variable').value.mean(), color='green', linewidth=5)

# Random baseline
ax1.axhline(y=np.mean(baseline), color='r', linestyle='--', linewidth=2, alpha=1)
ax2.axhline(y=np.mean(baseline), color='r', linestyle='--', linewidth=2, alpha=1)
ax3.axhline(y=np.mean(baseline), color='r', linestyle='--', linewidth=2, alpha=1)
# ax4.axhline(y=np.mean(baseline), color='r', linestyle='--', linewidth=2, alpha=1)

ax1.set_xlabel('Round')
ax1.set_ylabel('MI')
# ax2.set_ylabel('MI')
# ax3.set_ylabel('MI')
ax2.set_xlabel('Round')
ax3.set_xlabel('Round')
# ax4.set_xlabel('Round')

# set ylim to be 0-1 for all subplots
ax1.set_ylim(0, 1)
ax2.set_ylim(0, 1)
ax3.set_ylim(0, 1)
# ax4.set_ylim(0, 1)

plt.tight_layout()
plt.savefig('figures/Figure_5.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
plot_last_lexicons(a, n_iter, pos=-1, title='c_bias')
# Out:
# Number of distinct lexicon pairs: 20

# %%
plot_last_lexicons(b, n_iter, pos=-1, title='unbiased')
# Out:
# Number of distinct lexicon pairs: 20

# %%
plot_last_lexicons(c, n_iter, pos=-1, title='s_bias')
# Out:
# Number of distinct lexicon pairs: 20

# %% [markdown]
# ## Running with multiple N

# %%
SHAPE = (5, 5)

coords = np.array(np.meshgrid(np.arange(SHAPE[0]), np.arange(SHAPE[1]))).T.reshape(-1, 2)
coords = [tuple(i) for i in coords]


coords_dict = defaultdict(list)
for i, coord in enumerate(coords):
    coords_dict[tuple(coord)] = tuple(coord)

# %%
lexicons_convex, lexicons_nconvex, lexicons_simple, LS_, coords, coords_dict, mi_convex, mi_nconvex, mi_simple = efficiency_simplicity_analysis(1000, 
                                                                                                                                                 SHAPE, 
                                                                                                                                                 3, 10, 
                                                                                                                                                 beta=10,
                                                                                                                                                 n_iter=100,
                                                                                                                                                 n_rounds=10,
                                                                                                                                                 coords=coords,
                                                                                                                                                 coords_dict=coords_dict)
# Out:
# 100%|██████████| 7/7 [02:32<00:00, 21.73s/it]

# %%
# lexicons_convex, lexicons_nconvex, lexicons_simple, LS_, coords, coords_dict, mi_convex, mi_nconvex, mi_simple = efficiency_simplicity_analysis(10000, 
#                                                                                                                                                  SHAPE, 
#                                                                                                                                                  3, 10, 
#                                                                                                                                                  beta=0.1)

# %%
# plot mutual information distribution for all models 3 subplots
# fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(11, 3), sharey=True)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(9, 3), sharey=True)

# Convex subplot
ax1.hist(mi_convex, bins=20, density=True, color='blue', alpha=0.7)
ax1.set_xlabel('Mutual Information')
ax1.set_ylabel('Density')
ax1.set_title('Strong convexity bias', fontsize=12)

# Non-convex subplot
ax2.hist(mi_nconvex, bins=20, density=True, color='orange', alpha=0.7)
ax2.set_xlabel('Mutual Information')
ax2.set_title('No bias', fontsize=12)

# Simplicity subplot
ax3.hist(mi_simple, bins=20, density=True, color='red', alpha=0.7)
ax3.set_xlabel('Mutual Information')
ax3.set_title('Strong simplicity bias', fontsize=12)

# # Simplicity + convexity treshold subplot
# ax4.hist(mi_simple_convex, bins=20, density=True, color='green', alpha=0.7)
# ax4.set_xlabel('Mutual Information')
# ax4.set_title('Simplicity bias + treshold', fontsize=12)

# xlim to be 0-1
ax1.set_xlim(-0.1, 1.1)
ax2.set_xlim(-0.1, 1.1)
ax3.set_xlim(-0.1, 1.1)
# ax4.set_xlim(-0.1, 1.1)

plt.tight_layout()
plt.show()

# %%
# print mean and standard deviation of mutual information for each model
print(f"Mean MI for convexity biased agents: {np.mean(mi_convex):.3f} (std: {np.std(mi_convex):.3f})")
print(f"Mean MI for non biased agents: {np.mean(mi_nconvex):.3f} (std: {np.std(mi_nconvex):.3f})")
print(f"Mean MI for simplicity biased agents: {np.mean(mi_simple):.3f} (std: {np.std(mi_simple):.3f})")
# print(f"Mean MI for simplicity biased agents with convexity treshold: {np.mean(mi_simple_convex):.3f} (std: {np.std(mi_simple_convex):.3f})")
# Out:
# Mean MI for convexity biased agents: 0.639 (std: 0.084)
# Mean MI for non biased agents: 0.551 (std: 0.064)
# Mean MI for simplicity biased agents: 0.945 (std: 0.146)

# %%
# flatten each lexicon and store in a numpy array
lexicons_convex_ = np.array([lexicon.flatten() for lexicon in lexicons_convex])
lexicons_nconvex_ = np.array([lexicon.flatten() for lexicon in lexicons_nconvex])
lexicons_simple_ = np.array([lexicon.flatten() for lexicon in lexicons_simple])

# convert eahc individual lexicon to a string of numbers
lexicons_convex_str = np.array([''.join(map(str, lexicon)) for lexicon in lexicons_convex_])
lexicons_nconvex_str = np.array([''.join(map(str, lexicon)) for lexicon in lexicons_nconvex_])
lexicons_simple_str = np.array([''.join(map(str, lexicon)) for lexicon in lexicons_simple_])

# %%
# compute the number of unique lexicons for each model and the percentage that the top-10 lexicons represent
n_unique_convex = len(np.unique(lexicons_convex_str))
n_unique_nconvex = len(np.unique(lexicons_nconvex_str))
n_unique_simple = len(np.unique(lexicons_simple_str))

# print the number of unique lexicons for each model
print(f"Number of unique lexicons for convexity biased agents: {n_unique_convex}")
print(f"Number of unique lexicons for non biased agents: {n_unique_nconvex}")
print(f"Number of unique lexicons for simplicity biased agents: {n_unique_simple}")

# compute the percentage of the top-10 lexicons for each model
# count the number of times each lexicon appears
count_convex = Counter(lexicons_convex_str)
count_nconvex = Counter(lexicons_nconvex_str)
count_simple = Counter(lexicons_simple_str)

# get the top-10 lexicons for each model
top_10_convex = count_convex.most_common(10)
top_10_nconvex = count_nconvex.most_common(10)
top_10_simple = count_simple.most_common(10)

# compute the percentage of the top-10 lexicons for each model
top_10_convex_perc = sum([i[1] for i in top_10_convex]) / len(lexicons_convex_str)
top_10_nconvex_perc = sum([i[1] for i in top_10_nconvex]) / len(lexicons_nconvex_str)
top_10_simple_perc = sum([i[1] for i in top_10_simple]) / len(lexicons_simple_str)

# print the percentage of the top-10 lexicons for each model
print(f"Percentage of the top-10 lexicons for convexity biased agents: {top_10_convex_perc:.3f}")
print(f"Percentage of the top-10 lexicons for non biased agents: {top_10_nconvex_perc:.3f}")
print(f"Percentage of the top-10 lexicons for simplicity biased agents: {top_10_simple_perc:.3f}")
# Out:
# Number of unique lexicons for convexity biased agents: 733
# Number of unique lexicons for non biased agents: 1265
# Number of unique lexicons for simplicity biased agents: 157
# Percentage of the top-10 lexicons for convexity biased agents: 0.044
# Percentage of the top-10 lexicons for non biased agents: 0.022
# Percentage of the top-10 lexicons for simplicity biased agents: 0.657

# %%
fig, ax = plt.subplots(3, 10, figsize=(8, 3))

for i in range(10):
    ax[0, i].imshow(lexicons_convex[np.random.choice(range(len(lexicons_convex)))], cmap='tab20', interpolation='none')
    ax[1, i].imshow(lexicons_nconvex[np.random.choice(range(len(lexicons_nconvex)))], cmap='tab20', interpolation='none')
    ax[2, i].imshow(lexicons_simple[np.random.choice(range(len(lexicons_simple)))], cmap='tab20', interpolation='none')
    # ax[3, i].imshow(lexicons_simplicity_convex[np.random.choice(range(len(lexicons_simplicity_convex)))], cmap='tab20', interpolation='none')
    
    ax[0, i].axis('off')
    ax[1, i].axis('off')
    ax[2, i].axis('off')
    # ax[3, i].axis('off')

ax[0, 0].set_title('Convex', loc='left', fontsize=12)
ax[1, 0].set_title('Non-biased', loc='left', fontsize=12)
ax[2, 0].set_title('Simple', loc='left', fontsize=12)
# ax[3, 0].set_title('Simple + treshold', loc='left', fontsize=12)

plt.tight_layout()
# save to pdf
# plt.savefig('figures/study_2/lexicons.png')
plt.show()

# %%
# compute simplicity and informativeness for all types of models
simplicity_convex = [compression(lexicon) for lexicon in lexicons_convex]
informativeness_convex = [informativeness(lexicon, p_m=None, cielab_dict=coords_dict) for lexicon in lexicons_convex]

simplicity_nconvex = [compression(lexicon) for lexicon in lexicons_nconvex] 
informativeness_nconvex = [informativeness(lexicon, p_m=None, cielab_dict=coords_dict) for lexicon in lexicons_nconvex]

simplicity_simple = [compression(lexicon) for lexicon in lexicons_simple]
informativeness_simple = [informativeness(lexicon, p_m=None, cielab_dict=coords_dict) for lexicon in lexicons_simple]

# simplicity_simple_conv = [compression(lexicon) for lexicon in lexicons_simplicity_convex]
# informativeness_simple_conv = [informativeness(lexicon, p_m=None, cielab_dict=coords_dict) for lexicon in lexicons_simplicity_convex]

# compute simplicity for the prior
simplicity_prior = [compression(l) for l in LS_]
informativeness_prior = [informativeness(l, p_m=None, cielab_dict=coords_dict) for l in LS_]

# %%
pareto_front_indices = non_dominated_front(simplicity_prior, informativeness_prior) 
pareto_front_points = [(simplicity_prior[i], informativeness_prior[i]) for i in pareto_front_indices]

# %%
# find duplicates in either x or y and remove them
pareto_front_points = list(set(pareto_front_points))
x_pareto, y_pareto = zip(*pareto_front_points)

# create a smooth line over x_pareto and y_pareto using lowess
lowess = sm.nonparametric.lowess
smoothed = lowess(y_pareto, x_pareto)

# %%
LS_filtered = [lexicon for lexicon, informativeness in zip(LS_, informativeness_prior) if informativeness > 0]

# %%
len(LS_filtered)
# Out:
# 0

# %%
# plot distribution of informativeness from prior
fig, ax = plt.subplots(figsize=(6, 4))
sns.histplot(informativeness_prior, kde=True, color='grey')
# add a red line at 0
plt.axvline(x=0, color='red', linestyle='--', linewidth=2)
plt.xlabel('Informativeness')
plt.ylabel('Frequency')
plt.title('Informativeness distribution')
plt.tight_layout()
plt.show()

# %%
# compute the distance between the pareto front and the points
distances_convex = euclidean_distances([(simplicity, informativeness) for simplicity, informativeness in zip(simplicity_convex, informativeness_convex)], 
                                      smoothed)

distances_nconvex = euclidean_distances([(simplicity, informativeness) for simplicity, informativeness in zip(simplicity_nconvex, informativeness_nconvex)],
                                        smoothed)

distances_simple = euclidean_distances([(simplicity, informativeness) for simplicity, informativeness in zip(simplicity_simple, informativeness_simple)],
                                        smoothed)

# distances_simple_conv = euclidean_distances([(simplicity, informativeness) for simplicity, informativeness in zip(simplicity_simple_conv, informativeness_simple_conv)],
#                                         smoothed)

# convert to min distance for each point
distances_convex = np.min(distances_convex, axis=1)
distances_nconvex = np.min(distances_nconvex, axis=1)
distances_simple = np.min(distances_simple, axis=1)
# distances_simple_conv = np.min(distances_simple_conv, axis=1)

# %%
# fig, axs = plt.subplots(2, 3, figsize=(8, 5), squeeze=True, 
#                        gridspec_kw = {'height_ratios':[2, 1]})
fig, axs = plt.subplots(2, 3, figsize=(8, 4), squeeze=True, 
                        gridspec_kw = {'height_ratios':[2, 1]})

# Plot 1: Simplicity-Informativeness Biases
sc1 = axs[0, 0].scatter(simplicity_prior, informativeness_prior, alpha=0.1, color='grey', s=30)
sc1.set_rasterized(True)
axs[0, 0].scatter(simplicity_convex, informativeness_convex, alpha=0.5, marker='x', color='blue', s=60)
axs[0, 0].set_xlabel('Simplicity')
axs[0, 0].set_ylabel('Informativeness')
axs[0, 0].set_title('Convexity bias', fontsize=12)
axs[0, 0].plot(smoothed[:, 0], smoothed[:, 1], 'r--', alpha=1, linewidth=2)
axs[0, 0].set_ylim(None, 0)

sc2 = axs[0, 1].scatter(simplicity_prior, informativeness_prior, alpha=0.1, color='grey', s=30)
sc2.set_rasterized(True)
axs[0, 1].scatter(simplicity_nconvex, informativeness_nconvex, alpha=0.5, marker='x', color='orange', s=60)
axs[0, 1].set_xlabel('Simplicity')
axs[0, 1].set_ylabel('Informativeness')
axs[0, 1].set_title('Unbiased', fontsize=12)
axs[0, 1].plot(smoothed[:, 0], smoothed[:, 1], 'r--', alpha=1, linewidth=2)
axs[0, 1].set_ylim(None, 0)

sc3 = axs[0, 2].scatter(simplicity_prior, informativeness_prior, alpha=0.1, color='grey', s=30)
sc3.set_rasterized(True)
axs[0, 2].scatter(simplicity_simple, informativeness_simple, alpha=0.5, marker='x', color='red', s=60)
# rasterize the scatter plot
axs[0, 2].set_rasterization_zorder(1)
axs[0, 2].set_xlabel('Simplicity')
axs[0, 2].set_ylabel('Informativeness')
axs[0, 2].set_title('Simplicity bias', fontsize=12)
axs[0, 2].plot(smoothed[:, 0], smoothed[:, 1], 'r--', alpha=1, linewidth=2)
axs[0, 2].set_ylim(None, 0)

# sc4 = axs[0, 3].scatter(simplicity_prior, informativeness_prior, alpha=0.1, color='grey', s=30)
# sc4.set_rasterized(True)
# axs[0, 3].scatter(simplicity_simple_conv, informativeness_simple_conv, alpha=1, marker='x', color='green', s=60)
# axs[0, 3].set_xlabel('Simplicity')
# axs[0, 3].set_ylabel('Informativeness')
# axs[0, 3].set_title(' Weak simplicity bias \n with a convexity treshold', fontsize=12)
# axs[0, 3].plot(smoothed[:, 0], smoothed[:, 1], 'r--', alpha=1, linewidth=2)
# axs[0, 3].set_ylim(None, 0)

# Plot 2: Distance to Pareto Front
axs[1, 0].hist(distances_convex.ravel(), bins=10, color='blue', density=True, alpha=0.5)
axs[1, 0].axvline(np.median(distances_convex.mean()), color='k', linestyle='dashed', linewidth=2)
axs[1, 0].set_xlabel('Distance to Pareto front')
# write the mean value in the top right corner of the plot
axs[1, 0].text(1.5, 3.5, f"Mean: {np.mean(distances_convex.mean()):.2f}", fontsize=10, ha='center')
axs[1, 0].set_xlim(0, 2)
axs[1, 0].set_ylim(0, 5)

axs[1, 1].hist(distances_nconvex.ravel(), bins=20, color='orange', density=True, alpha=0.5)
axs[1, 1].axvline(np.median(distances_nconvex.mean()), color='k', linestyle='dashed', linewidth=2)
axs[1, 1].set_xlabel('Distance to Pareto front')
axs[1, 1].text(1.5, 3.5, f"Mean: {np.mean(distances_nconvex.mean()):.2f}", fontsize=10, ha='center')
axs[1, 1].set_xlim(0, 2)
axs[1, 1].set_ylim(0, 5)

axs[1, 2].hist(distances_simple.ravel(), bins=10, color='red', density=True, alpha=0.5)
axs[1, 2].axvline(np.median(distances_simple.mean()), color='k', linestyle='dashed', linewidth=2)
axs[1, 2].set_xlabel('Distance to Pareto front')
axs[1, 2].text(1.5, 3.5, f"Mean: {np.mean(distances_simple.mean()):.2f}", fontsize=10, ha='center')
axs[1, 2].set_xlim(0, 2)
axs[1, 2].set_ylim(0, 5)

# axs[1, 3].hist(distances_simple_conv.ravel(), bins=10, color='green', density=True, alpha=0.5)
# axs[1, 3].axvline(np.median(distances_simple_conv.mean()), color='k', linestyle='dashed', linewidth=2)
# axs[1, 3].set_xlabel('Distance to Pareto front')
# axs[1, 3].text(1.5, 3.5, f"Mean: {np.mean(distances_simple_conv.mean()):.2f}", fontsize=10, ha='center')
# axs[1, 3].set_xlim(0, 2)
# axs[1, 3].set_ylim(0, 5)

plt.tight_layout()
sns.despine()
# save the figure
plt.savefig('figures/Figure_6.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
# print mean informativeness and simplicity for each model (add sd as well)
print(f"Mean simplicity for convex model: {np.mean(simplicity_convex):.3f} (SD: {np.std(simplicity_convex):.3f})")

print(f"Mean simplicity for unbiased model: {np.mean(simplicity_nconvex):.3f} (SD: {np.std(simplicity_nconvex):.3f})")

print(f"Mean simplicity for simplicity model: {np.mean(simplicity_simple):.3f} (SD: {np.std(simplicity_simple):.3f})")

# print(f"Mean simplicity for simplicity model with treshold: {np.mean(simplicity_simple_conv):.3f} (SD: {np.std(simplicity_simple_conv):.3f})")

print(f"Mean informativeness for convex model: {np.mean(informativeness_convex):.3f} (SD: {np.std(informativeness_convex):.3f})")

print(f"Mean informativeness for unbiased model: {np.mean(informativeness_nconvex):.3f} (SD: {np.std(informativeness_nconvex):.3f})")

print(f"Mean informativeness for simplicity model: {np.mean(informativeness_simple):.3f} (SD: {np.std(informativeness_simple):.3f})")

# print(f"Mean informativeness for simplicity model with treshold: {np.mean(informativeness_simple_conv):.3f} (SD: {np.std(informativeness_simple_conv):.3f})")
# Out:
# Mean simplicity for convex model: 3.829 (SD: 0.141)
# Mean simplicity for unbiased model: 3.898 (SD: 0.138)
# Mean simplicity for simplicity model: 3.653 (SD: 0.173)
# Mean informativeness for convex model: -4.010 (SD: 0.636)
# Mean informativeness for unbiased model: -3.945 (SD: 0.701)
# Mean informativeness for simplicity model: -4.219 (SD: 0.455)
